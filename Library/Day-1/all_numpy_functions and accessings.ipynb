# %% [markdown]
# import numpy

# %%
import numpy as np

# %% [markdown]
# lets initialize arrays and use functions

# %%
a = np.array([1,2,3,4,5])
## a = np.array([1,2,3,4,5],dtype='int16')
print(a)                       # 1 d array
# Out:
# [1 2 3 4 5]

# %%
b = np.array([[1.0,2.2,3.0,4.4],[3.3,4.1,5.2,7.7]])
print(b)                         # 2 D array
# Out:
# [[1.  2.2 3.  4.4]
#  [3.3 4.1 5.2 7.7]]

# %% [markdown]
# using some functions

# %%
a.ndim       ## used to print dimensions of array
# Out:
# 1

# %%
b.ndim          ## used to print dimensions of array
# Out:
# 2

# %%
a.shape
# Out:
# (5,)

# %%
b.shape   # to print the shape of array like its dimensions and no of values in each dimension
# Out:
# (2, 4)

# %%
a.dtype
# Out:
# dtype('int64')

# %%
b.dtype               ## in all if we dont define data tyope it will show 64 but we can define it  as shown above
# Out:
# dtype('float64')

# %%
a.itemsize           # as int 32 has 8 bits
# Out:
# 8

# %%
b.itemsize
# Out:
# 8

# %%
a.nbytes
# Out:
# 40

# %%
b.nbytes
# Out:
# 64

# %% [markdown]
# how to access elements from and array using row and colum

# %%
b[1,3]= 6.9
print(b)
# Out:
# [[1.  2.2 3.  4.4]
#  [3.3 4.1 5.2 6.9]]

# %% [markdown]
# : use to get entire row or column

# %%
b[:,0]= 1.1
print(b)
# Out:
# [[1.1 2.2 3.  4.4]
#  [1.1 4.1 5.2 6.9]]

# %%
b[0,:]=[1.1,2.9,3.1,4.9]
print(b)
# Out:
# [[1.1 2.9 3.1 4.9]
#  [1.1 4.1 5.2 6.9]]

# %% [markdown]
# 3-d array
# ([[[]]])= 3d
# ([[]])= 2 d
# ([])= 1 d

# %%
c = np.array([[[1,2],[1,3]],[[1,4],[4,5]]])
print(c)
# Out:
# [[[1 2]
#   [1 3]]
#
#  [[1 4]
#   [4 5]]]

# %% [markdown]
# c[layer,row,column]

# %%
c[0,1,1]
# Out:
# np.int64(3)

# %%
c[0,1,1]= 4
print(c)
# Out:
# [[[1 2]
#   [1 4]]
#
#  [[1 4]
#   [4 5]]]

# %%
c[:,0,:]  ## print first rows of both layer
# Out:
# array([[1, 2],
#        [1, 4]])

# %%
c[:,:,0]
# Out:
# array([[1, 1],
#        [1, 4]])
