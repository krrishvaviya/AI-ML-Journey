# %% [markdown]
# <a href="https://colab.research.google.com/github/krrishvaviya/AI-ML-Journey/blob/main/python_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# how to create and use the word/number etc from the generated list
# list is to be generated using [] where these 2 brackets can store any value like word,bool exp , number

# %%
name =["krrish", "raj" , "meet" , "yash"]
print(name[0])
print(name[1])
print(name[2])                 ##  the inzexing starts from 0
print(name[3])
print(name[1:2])
print(name[1:3])                 #to access multiple values from string use this 1:3 from where to where u want
name[2] ="bauna"                  #how to edit in list
print(name[2])
# Out:
# krrish
# raj
# meet
# yash
# ['raj']
# ['raj', 'meet']
# bauna

# %% [markdown]
# funcions of list

# %%
list_1 = [1,2,3,4,5,66,77,33]
list_2 = ["krrish", "raj" , "meet" ,  "meet" ,"yash"]
count = (list_2.count("meet"))         ## to count same characters in one list
print (count)
list_2.append("aryan")
print(list_2)
list_2.extend(list_1)
print(list_2)
list_3 = list_1.copy()
print (list_3)
list_2.reverse()
print (list_2)
list_2.pop()
print(list_2)
list_2.pop(10)
print(list_2)
# Out:
# 2
# ['krrish', 'raj', 'meet', 'meet', 'yash', 'aryan']
# ['krrish', 'raj', 'meet', 'meet', 'yash', 'aryan', 1, 2, 3, 4, 5, 66, 77, 33]
# [1, 2, 3, 4, 5, 66, 77, 33]
# [33, 77, 66, 5, 4, 3, 2, 1, 'aryan', 'yash', 'meet', 'meet', 'raj', 'krrish']
# [33, 77, 66, 5, 4, 3, 2, 1, 'aryan', 'yash', 'meet', 'meet', 'raj']
# [33, 77, 66, 5, 4, 3, 2, 1, 'aryan', 'yash', 'meet', 'raj']

# %% [markdown]
# TUPLES
# tuples are the variables created that cant be modified/deleted/added etc thats called immutable
#
#
# but lists are created using square brackets[] and Tuples are created using double paranthesis()

# %%
avariable =(4,5,7,4)
print(avariable[1])
print(avariable[2])
print(avariable[0])
print(avariable.count(4))
# Out:
# 5
# 7
# 4
# 2

# %% [markdown]
# FRUNCTIONs
# Functions are defined once at the top and the can be used where ever need and many times helps to arrange the code

# %%
def say_hellow(name, age):                  ## here i defined a function
  print(f"Hellow {name} ur age is {age}")   ## here we can write or perform tasks that will be performed when the function is called

say_hellow("krrish",20)                     ## here i called he function i defined and the (can be used to write variables or data)
say_hellow("raj",21)
# Out:
# Hellow krrish ur age is 20
# Hellow raj ur age is 21

# %%
num1 = []
num1 = input ("enter name ")
num1 = input ("enter age")
num1 = input ("enter fees status ")
print (num1)
# Out:
# enter name krrish
# enter age20
# enter fees status paid
# paid
